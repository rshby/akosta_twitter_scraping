# %%
import pandas as pd
import numpy as np
import tweepy
import twitter_scraper
from twitter_scraper import get_tweets
import time

# %%
consumer_key = "CvqQayDOgXrYhscT4VwcrQd2l"
consumer_secret = "PKLBaNA7hbr4D21fPDY1ictxkmFfFWWUAyTemYxpN48lG90tIe"
access_token = "538784946-mIHrfx9WOtLtTu2Ckp2WmgoBHxcrISOgHcfOHCve"
access_token_secret = "1mqLBMnByoIrBqNzWpSmpfZPstgAdfxHi3iHyao4Ovp12"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# # Keywords "mamikost"

# %%
text_query = 'mamikost'  # keyword
max_tweets = 500  # jumlah data yang discraping
 
tweets = tweepy.Cursor(api.search,q=text_query).items(max_tweets)
 
# tuliskan parameter(kolom) apa saja yang akan discraping
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.created_at, tweet.user.profile_image_url_https, tweet.lang] for tweet in tweets]

# simpan hasil scraping ke dalam DataFrame
df_mamikost = pd.DataFrame(tweets_list)
df_mamikost.columns = ["text", "created_at", "tweet_id", "user_profile_name", "username", "user_id", "user_location", "user_url", "user_desc", "user_verified", "user_followers_count", "user_friend_counts", "user_favourites_count", "user_statuses_count", "user_created_at", "user_profile_image_url", "lang"]

# %%
df_mamikost
# Out:
#                                                 text          created_at  \
# 0                 @mks_fess Cek di aplikasi mamikost 2021-09-20 16:27:25
# 1         @weed69_420 @contritum_fan @mamikost mikum 2021-09-19 07:58:15
# 2          Kerjaan gue skgr liat2 kostan di mamikost 2021-09-18 13:34:05
# 3                 @bertanyarl Cari di Mamikost nder. 2021-09-18 08:00:22
# 4  @sbyfess Mamikost \nLak butuh info kost cewek ... 2021-09-17 05:08:48
# 5  @jogmfs Buka mamikost, filter area dan opsi ca... 2021-09-17 03:03:50
# 6  @enzaaofc_ Jakselnya dmn kak? Mamikost coba ad... 2021-09-16 15:46:46
# 7  Mamikost kepake setelah gw delete appnya, tiba... 2021-09-15 15:00:55
# 8  @Detatika Eh ini yg dipake di mamikost bukan s... 2021-09-14 03:15:04
# 9                        @Askrlfess cari di mamikost 2021-09-13 01:06:03
#
#               tweet_id          user_profile_name        username  \
# 0  1439989584142635008                        Jan       amerfati_
# ...

# %% [markdown]
# # Keyword "mamikos"

# %%
text_query = 'mamikos'  # keyword
max_tweets = 500  # jumlah data yang discraping
 
tweets = tweepy.Cursor(api.search,q=text_query).items(max_tweets)
 
# tuliskan parameter(kolom) apa saja yang akan discraping
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.created_at, tweet.user.profile_image_url_https, tweet.lang] for tweet in tweets]

# simpan hasil scraping ke dalam DataFrame
df_mamikos = pd.DataFrame(tweets_list)
df_mamikos.columns = ["text", "created_at", "tweet_id", "user_profile_name", "username", "user_id", "user_location", "user_url", "user_desc", "user_verified", "user_followers_count", "user_friend_counts", "user_favourites_count", "user_statuses_count", "user_created_at", "user_profile_image_url", "lang"]

# %%
df_mamikos
# Out:
#                                                   text          created_at  \
# 0    Rekomendasi kosan hari ini adala Kos Parman Mi... 2021-09-21 05:00:00
# 1    Haloo Ges, rekomendasi kosan hari ini adalah  ... 2021-09-21 03:00:01
# 2    @ngalamfess Cek mamikos aja nder banyak bgt wk... 2021-09-21 02:39:43
# 3                   Coba dulu maba uda tau apk mamikos 2021-09-21 01:26:11
# 4    Haloo Ges, rekomendasi kosan hari ini adalah K... 2021-09-21 00:00:01
# ..                                                 ...                 ...
# 137  @lthfnd ada kos murah daerah jakbar, cek aja d... 2021-09-13 02:36:17
# 138  gua liat di mamikos kosan di tembalang mahal b... 2021-09-13 02:08:30
# 139                            https://t.co/huVqph3Zk4 2021-09-13 01:26:23
# 140  @xxeurekaa @aarthasy @mantanmoo_ @jayasbel Nem... 2021-09-12 14:03:57
# 141  @txtdarikostan Mau nambah laptop aja harus bil... 2021-09-12 13:38:09
#
#                 tweet_id user_profile_name         username  \
# ...

# %% [markdown]
# # keyword "mami kos"

# %%
text_query = 'mami kos'  # keyword
max_tweets = 500  # jumlah data yang discraping
 
tweets = tweepy.Cursor(api.search,q=text_query).items(max_tweets)
 
# tuliskan parameter(kolom) apa saja yang akan discraping
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.created_at, tweet.user.profile_image_url_https, tweet.lang] for tweet in tweets]

# simpan hasil scraping ke dalam DataFrame
df_mami_kos = pd.DataFrame(tweets_list)
df_mami_kos.columns = ["text", "created_at", "tweet_id", "user_profile_name", "username", "user_id", "user_location", "user_url", "user_desc", "user_verified", "user_followers_count", "user_friend_counts", "user_favourites_count", "user_statuses_count", "user_created_at", "user_profile_image_url", "lang"]

# %%
df_mami_kos
# Out:
#                                                   text          created_at  \
# 0                        Oke 2 jam buka mami kos doang 2021-09-21 03:55:08
# 1    @brigitiritimiri Waww semangat hunting kos git... 2021-09-21 01:12:12
# 2    @kos_dreamer @keniaos @keniaos mami mira estoo... 2021-09-20 22:51:48
# 3    Kok sotoy bgt potong rambut deweeee. Seperti l... 2021-09-20 14:46:07
# 4       ini alice apa mami kos https://t.co/sH1kUeVuLy 2021-09-20 14:14:38
# ..                                                 ...                 ...
# 166  @keniaos mami manda la ubicación ya tienes mi ... 2021-09-12 20:25:20
# 167  @Dieg0_KOs Obvio que la opinión de su mami cue... 2021-09-12 19:55:31
# 168  tabangan jud kos mga boang oh founder jud nis ... 2021-09-12 17:21:07
# 169       @keniaos AAAAAAA Mami la vas a romper &lt;33 2021-09-12 16:57:35
# 170  Keinget pas itu. Mamiku mau ke kos, trus aku d... 2021-09-12 16:37:33
#
#                 tweet_id user_profile_name        username  \
# ...

# %% [markdown]
# # keyword "mami kost"

# %%
text_query = 'mami kost'  # keyword
max_tweets = 500  # jumlah data yang discraping
 
tweets = tweepy.Cursor(api.search,q=text_query).items(max_tweets)
 
# tuliskan parameter(kolom) apa saja yang akan discraping
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.created_at, tweet.user.profile_image_url_https, tweet.lang] for tweet in tweets]

# simpan hasil scraping ke dalam DataFrame
df_mami_kost = pd.DataFrame(tweets_list)
df_mami_kost.columns = ["text", "created_at", "tweet_id", "user_profile_name", "username", "user_id", "user_location", "user_url", "user_desc", "user_verified", "user_followers_count", "user_friend_counts", "user_favourites_count", "user_statuses_count", "user_created_at", "user_profile_image_url", "lang"]

# %%
df_mami_kost
# Out:
#                                                  text          created_at  \
# 0   Liburan selesaii, kembali menjadi istri sholeh... 2021-09-21 04:42:14
# 1   @brigitiritimiri Waww semangat hunting kos git... 2021-09-21 01:12:12
# 2          nyari info kost selain mami kost apa yaaa? 2021-09-20 14:58:53
# 3                           @uinwsfess Mami kost coba 2021-09-20 03:08:01
# 4   @vanillamarke coba deh di mami kost atau blusu... 2021-09-19 16:24:34
# 5      @aniscarhy Dah nyoba nyari di mami kost belum? 2021-09-19 16:01:32
# 6   Nyari kosan di daerah Margonda Depok dan sekit... 2021-09-18 08:31:49
# 7   @jogmfs Cek di aplikasi mami kost aja\nSesuain... 2021-09-18 05:09:52
# 8   Mampus ga tuh pas liat kos katanya diliatin ka... 2021-09-18 03:17:54
# 9                                  @jogmfs mami, kost 2021-09-17 15:23:34
# 10            @enzaaofc_ Coba cari di mami kost enzaa 2021-09-16 14:32:39
# 11                 @um_fess cek di apk mami kost coba 2021-09-15 09:49:31
# ...

# %% [markdown]
# # Gabungkan semua data

# %%
df = pd.concat([df_mamikos, df_mamikost, df_mami_kos, df_mami_kost], ignore_index=True)

# %%
df["text"] = df["text"].str.lower()

# %%
df = df[df["lang"] == "in"]
df.reset_index(drop=True, inplace=True)

# %%
df["lang"].value_counts()
# Out:
# in    178
# Name: lang, dtype: int64

# %%
df.to_feather("dataMamiKostIndonesia.feather")

# %%
# Out:
#                                                   text          created_at  \
# 0    rekomendasi kosan hari ini adala kos parman mi... 2021-09-21 05:00:00
# 1    haloo ges, rekomendasi kosan hari ini adalah  ... 2021-09-21 03:00:01
# 2    @ngalamfess cek mamikos aja nder banyak bgt wk... 2021-09-21 02:39:43
# 3                   coba dulu maba uda tau apk mamikos 2021-09-21 01:26:11
# 4    haloo ges, rekomendasi kosan hari ini adalah k... 2021-09-21 00:00:01
# ..                                                 ...                 ...
# 334                 @um_fess cek di apk mami kost coba 2021-09-15 09:49:31
# 335  @ntet__ haha ayok lagi ❤️❤️ awalnya sebel maca... 2021-09-13 16:13:08
# 336  @hrdbacot mami kost segera daftar akun linked ... 2021-09-13 15:19:37
# 337     ada yg pernah sewa kost lewat mami kost tidak? 2021-09-13 10:46:56
# 338  jog ada cewe yang kost di bantul ga ya? kalo a... 2021-09-12 22:50:37
#
#                 tweet_id       user_profile_name        username  \
# ...
