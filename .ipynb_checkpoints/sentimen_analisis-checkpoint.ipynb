# %%
import pandas as pd
from textblob import TextBlob
import numpy as np
pd.set_option('display.max_colwidth', -1)
from deep_translator import GoogleTranslator
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="talk")
# Out:
# C:\Users\ROG\AppData\Local\Temp/ipykernel_1420/2057072921.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df = (pd.read_feather("dataset/data_kalimat_clean.feather").loc[:, ["text", "kalimat_clean"]])
df["kalimat_clean"] = df["kalimat_clean"].str.replace("rt", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("sbmptnfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("tegalfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("https", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("sbyfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("keniaos", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("wkwk", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("collegemenfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("que", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("melankos", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("jogmfs", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("undipmenfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("ngalamfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("ubsansfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("karawangfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("stanmenfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("schfess", "")
df["kalimat_clean"] = df["kalimat_clean"].str.replace("utbkfess", "")
df = df.drop(19, axis="rows").reset_index(drop=True)

# %%
df["kalimat_en"] = ""
for i in range(len(df["kalimat_clean"])):
    df["kalimat_en"][i] = GoogleTranslator(source="auto", target="en").translate(df["kalimat_clean"][i])

# %%
df['sentiment'] = df['kalimat_en'].apply(lambda tweet: TextBlob(tweet).sentiment.polarity)

# %%
df["sentiment"].value_counts(dropna=False)
# Out:
#  0.000000    124
#  0.100000    8
#  0.200000    5
#  0.450000    3
#  0.550000    3
#  0.500000    3
#  0.400000    3
#  0.285714    2
#  0.150000    2
#  0.042857    2
# -0.500000    1
#  0.316667    1
# -0.250000    1
#  0.116667    1
#  0.356250    1
#  0.250000    1
#  0.408333    1
#  0.433333    1
# -0.075000    1
#  0.300000    1
# -0.200000    1
# -0.085185    1
#  0.800000    1
# -0.033333    1
# -0.063889    1
#  0.053333    1
# -0.100000    1
#  0.700000    1
#  0.350000    1
# -0.150000    1
# -0.050000    1
# -0.300000    1
# Name: sentiment, dtype: int64

# %%
df["sentiment_label"] = pd.cut(df["sentiment"], bins=[-1, -0.001, 0.001, 1], labels=['negatif', 'netral', 'positif'])

# %%
# df.to_feather("dataset/data_sentiment.feather")

# %%
df
# Out:
#                                                                                                                                                text  \
dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 6), constrained_layout=True)
_ = fig.suptitle("Perbandingan Analisis Sentimen")
_ = sns.countplot(df["sentiment_label"])
_ = ax.set_yticks([11, 42, 124])
_ = ax.set_xlabel("Jenis Sentimen")
_ = ax.set_ylabel("Jumlah Data")
plt.show()

# %%
df = pd.read_feather("dataset/data_sentiment.feather")

# %%
df
# Out:
#                                                                                                                                                text  \
# 0    rekomendasi kosan hari ini adala kos parman minara bandara soekarno hatta taman mahkota benda tangerang 912pa\n\nkosa… https://t.co/7xfgwzwsjr
# 1    haloo ges, rekomendasi kosan hari ini adalah  kos pegangsaan tipe a kelapa dua jakarta utara\n\nkosannya sudah isian… https://t.co/h6agqi10go
# 2    @ngalamfess cek mamikos aja nder banyak bgt wkwk :(
# 3    coba dulu maba uda tau apk mamikos
# 4    haloo ges, rekomendasi kosan hari ini adalah kos hans sungai bambu tanjung priuk jakarta utara\n\nkosannya sudah isia… https://t.co/8lhjqtbovn
# ..                                                                                                                                              ...
# 172  @um_fess cek di apk mami kost coba
# 173  @ntet__ haha ayok lagi ❤️❤️ awalnya sebel macam di buat anak mami sama security nya kost aku ternyata wkwkwkwk ada udang di balik udang 🤣
# 174  @hrdbacot mami kost segera daftar akun linked wkwk
# 175  ada yg pernah sewa kost lewat mami kost tidak?
# 176  jog ada cewe yang kost di bantul ga ya? kalo ada rep dong kalo cocok mau kost disitu jg nyari di mami kost gada yang cocok:(
#
#                                                                                        kalimat_clean  \
# 0    rekomendasi kosan adala kos parman minara bandara soekarno hatta taman mahkota benda tangerang
# 1    haloo ges rekomendasi kosan kos pegangsaan tipe kelapa jakaa utara kosannya
# 2     cek mamikos aja nder bgt
# 3    coba maba uda tau apk mamikos
# 4    haloo ges rekomendasi kosan kos hans sungai bambu tanjung priuk jakaa utara kosannya
# ..                                                                                     ...
# 172  cek apk mami kost coba
# 173  haha ayok sebel anak mami security kost  udang udang
# 174  hrdbacot mami kost daftar akun linked
# 175  yg sewa kost mami kost
# 176  jog cewe kost bantul ga kalo rep kalo cocok kost disitu jg nyari mami kost gada cocok
#
#                                                                                                                                          kalimat_en  \
# 0    The recommendation for boarding houses is Parman Minara boarding house Soekarno Hatta Airport, Taman Mahkota Benda, Tangerang
# 1    hello guys, recommendations for the boarding house for the Kelapa Jaka type North Jakarta boarding house
# 2    check mamikos, it's great
# 3    try mamikos already know apk mamikos
# 4    hello ges recommendation for Hans boarding house, bamboo river, cape priuk, jakaa north of his boarding house
# ..                                                                                                             ...
# 172  check the apk mami boarding try
# 173  haha, let's be annoying, mami's child security, prawn boarding house
# 174  hrdbacot mami boarding account list linked
# 175  the one who rents the boarding house, mommy boarding house
# 176  Jog, a boarding house girl, can you help if the rep is suitable, the boarding house is there, looking for a boarding house mami, doesn't match
#
#      sentiment sentiment_label
# 0    0.00       netral
# 1    0.00       netral
# 2    0.80       positif
# 3    0.00       netral
# 4    0.00       netral
# ..    ...          ...
# 172  0.00       netral
# 173 -0.30       negatif
# 174  0.00       netral
# 175  0.00       netral
# 176  0.55       positif
#
# [177 rows x 5 columns]

# %%
df.to_csv("dataset/data_sentiment.csv")
